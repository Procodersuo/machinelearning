# %%
import seaborn as sns
import pandas as pd
import matplotlib.pylab as plt

# %%
titanic=sns.load_dataset("titanic")
titanic.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 776         0       3    male   NaN      0      0   7.750        Q   Third
# 225         0       3    male  22.0      0      0   9.350        S   Third
# 553         1       3    male  22.0      0      0   7.225        C   Third
# 570         1       2    male  62.0      0      0  10.500        S  Second
# 290         1       1  female  26.0      0      0  78.850        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 776    man        True    F   Queenstown    no   True
# 225    man        True  NaN  Southampton    no   True
# 553    man        True  NaN    Cherbourg   yes   True
# 570    man        True  NaN  Southampton   yes   True
# 290  woman       False  NaN  Southampton   yes   True

# %%
sns.barplot(x=titanic['sex'],y=titanic['fare'],hue=titanic['pclass'])
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_length'>

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'], hue=tips['sex'],style=tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 scale=StandardScale()
#       2 X_train,X_test,Y_train,Y_test
#
# NameError: name 'StandardScale' is not defined
