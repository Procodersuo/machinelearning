# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("E:\ml\Scaling\Social_Network_Ads.csv")
df=df.iloc[:,2:]
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased', axis=1),df['Purchased'], random_state=0, test_size=0.3)
X_train
# Out:
#      Age  EstimatedSalary
# 92    26            15000
# 223   60           102000
# 234   38           112000
# 232   40           107000
# 377   42            53000
# ..   ...              ...
# 323   48            30000
# 192   29            43000
# 117   36            52000
# 47    27            54000
# 172   26           118000
#
# [280 rows x 2 columns]

# %%
scaler=StandardScaler()
scaler.fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)
temp=pd.DataFrame(X_train_scaled)
# Out:
#                   0             1
# count  2.800000e+02  2.800000e+02
# mean   3.489272e-17  6.344132e-17
# std    1.001791e+00  1.001791e+00
# min   -1.947491e+00 -1.584970e+00
# 25%   -7.710131e-01 -7.752370e-01
# 50%   -8.473441e-02  2.003677e-02
# 75%    7.976239e-01  5.261201e-01
# max    2.170181e+00  2.319101e+00

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr_scaled=LogisticRegression()
lr.fit(X_train,y_train)
lr_scaled.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
prediction=lr.predict(X_test)
predictionscaled=lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,prediction))
print(accuracy_score(y_test,predictionscaled))
# Out:
# 0.875
# 0.8666666666666667

# %%
# Out:
# [0.020804438280166437,
#  0.04299583911234397,
#  0.06934812760055478,
#  1.0,
#  0.04022191400832178,
#  0.027739251040221916,
#  0.052704576976421634,
#  0.0,
#  0.038834951456310676,
#  0.013869625520110958]
