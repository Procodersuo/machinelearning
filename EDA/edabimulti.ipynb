# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
tipsdf=sns.load_dataset("tips")
titanic=pd.read_csv("E:\ml\EDA\Titatinc.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12556\3113137434.py:2: SyntaxWarning: invalid escape sequence '\m'
#   titanic=pd.read_csv("E:\ml\EDA\Titatinc.csv")
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# SCATER PLOT (Numerical to Numerical)

# %%
sns.scatterplot(x=tipsdf['total_bill'],y=tipsdf['tip'], hue=tipsdf['sex'], style=tipsdf['smoker'],)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Bar Plot(Numerical - Categorical)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.barplot(x=titanic['Pclass'], y=titanic['Fare'],hue=titanic["Sex"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# Box Plate (Numerical Categorical)

# %%
sns.boxplot(x=titanic['Sex'],y=titanic['Age'],hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# Distplot

# %%
sns.displot(titanic[titanic['Survived']==0]['Age'])
# Out:
#   Cell In[37], line 1
#     sns.displot(hist=False,titanic[titanic['Survived']==0]['Age'])
#                                                                  ^
# SyntaxError: positional argument follows keyword argument
