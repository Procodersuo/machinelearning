# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("E:\ml\encoding\customer.csv")
df=df.iloc[:,2:]
df.sample(10)
# Out:
#      review education purchased
# 3      Good        PG        No
# 23     Good    School        No
# 40     Good    School        No
# 37  Average        PG       Yes
# 35     Poor    School       Yes
# 33     Good        PG       Yes
# 14     Poor        PG       Yes
# 34  Average    School        No
# 27     Poor        PG        No
# 16     Poor        UG       Yes

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df.drop("purchased", axis=1),
                                               df["purchased"],
                                               test_size=0.2,random_state=0)
ordenc=OrdinalEncoder(categories=[
    ['Poor','Average','Good'],['School','UG','PG']
    ])
ordenc.fit(X_train)
print(Y_train)
X_train=ordenc.transform(X_train)
# Out:
# 33    Yes
# 35    Yes
# 26     No
# 34     No
# 18     No
# 7     Yes
# 14    Yes
# 45    Yes
# 48    Yes
# 29    Yes
# 15     No
# 30     No
# 32    Yes
# 16    Yes
# 42    Yes
# 20    Yes
# 43     No
# 8      No
# 13     No
# 25     No
# 5     Yes
# 17    Yes
# 40     No
# 49     No
# 1      No
# 12     No
# 37    Yes
# 24    Yes
# 6      No
# 23     No
# 36    Yes
# 21     No
# 19    Yes
# 9     Yes
# 39     No
# 46     No
# 3      No
# 0      No
# 47    Yes
# 44     No
# Name: purchased, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(Y_train)
Y_train=le.transform(Y_train)
Y_test=le.transform(Y_test)
#y test have get some number insted of yes or no
